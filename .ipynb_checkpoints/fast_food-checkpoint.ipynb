# %% [markdown]
# # ETL Project

# %% [markdown]
# ## Import Dependencies and Setup

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %% [markdown]
# ## Extract data

# %%
fast_food_file = 'Resources/Fast_Food_Restaurants.csv'

# %%
#Fast food dataframe
fast_food_df = pd.read_csv(fast_food_file)
fast_food_df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AWrSh_KgsVYjT2BJAzaH  2019-05-19T23:58:05Z  2019-05-19T23:58:05Z
# 1  AWEKlA-LIxWefVJwxG9B  2018-01-18T18:30:23Z  2019-05-19T23:45:05Z
# 2  AWrSfAcYsVYjT2BJAzPt  2019-05-19T23:45:04Z  2019-05-19T23:45:04Z
# 3  AWrSa3NAQTFama1Xpkbz  2019-05-19T23:26:58Z  2019-05-19T23:26:58Z
# 4  AWrSaVGzZ4Yw-wtdgcaB  2019-05-19T23:24:38Z  2019-05-19T23:24:38Z
#
#                  address                                         categories  \
# 0       2555 11th Avenue  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1  2513 Highway 6 And 50  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2    1125 Patterson Road  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3    3455 N Salida Court  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4   5225 E Colfax Avenue  Fast Food Restaurants,Mexican Restaurants,Rest...
#
#                primaryCategories            city country  \
# 0  Accommodation & Food Services         Greeley      US
# 1  Accommodation & Food Services  Grand Junction      US
# 2  Accommodation & Food Services  Grand Junction      US
# 3  Accommodation & Food Services          Aurora      US
# 4  Accommodation & Food Services          Denver      US
#
#                                                 keys  latitude  longitude  \
# 0             us/co/greeley/255511thavenue/554191587  40.39629 -104.69699
# 1   us/co/grandjunction/2513highway6and50/1550891556  39.08135 -108.58689
# 2  us/co/grandjunction/1125pattersonroad/-2137447852  39.09148 -108.55411
# 3           us/co/aurora/3455nsalidacourt/1143321601  39.76369 -104.77671
# 4          us/co/denver/5225ecolfaxavenue/-864103396  39.74044 -104.92636
#
#                      name postalCode province  \
# 0              Carl's Jr.      80631       CO
# 1                Del Taco      81505       CO
# 2              Which Wich      81506       CO
# 3  Chipotle Mexican Grill      80011       CO
# 4               Taco Bell      80220       CO
#
#                                           sourceURLs  \
# 0  https://www.yellowpages.com/greeley-co/mip/car...
# 1  http://www.citysearch.com/profile/772076870/gr...
# 2  https://www.yellowpages.com/grand-junction-co/...
# 3  https://www.yellowpages.com/aurora-co/mip/chip...
# 4  https://www.yellowpages.com/denver-co/mip/taco...
#
#                                             websites
# 0  https://www.carlsjr.com/?utm_source=Yextandutm...
# 1                             http://www.deltaco.com
# 2                           http://www.whichwich.com
# 3                            http://www.chipotle.com
# 4  https://locations.tacobell.com/co/denver/5225-...

# %% [markdown]
# ## Transforming data

# %%
#Creating a filtered dataframe from specific columns
fast_food_cols = ['id', 'categories', 'city', 'name', 'province']
fast_food_transformed = fast_food_df[fast_food_cols].copy()
fast_food_transformed
# Out:
#                         id                                         categories  \
# 0     AWrSh_KgsVYjT2BJAzaH  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1     AWEKlA-LIxWefVJwxG9B  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2     AWrSfAcYsVYjT2BJAzPt  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3     AWrSa3NAQTFama1Xpkbz  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4     AWrSaVGzZ4Yw-wtdgcaB  Fast Food Restaurants,Mexican Restaurants,Rest...
# ...                    ...                                                ...
# 9995  AVwd7U0T_7pvs4fz-fS_  American Restaurants,Caterers,Soul Food Restau...
# 9996  AV1XW1fF3D1zeR_xFKHL  Mexican Restaurants,Caterers,Delicatessens,Iri...
# 9997  AV5UVbkiRxPSIh2RiQxV  Carry-out food,Hot dog restaurants,Fast Food R...
# 9998  AVwc9BxYByjofQCxj_GW  Carry-out food,Caterers,Restaurant delivery se...
# 9999  AVzA_GF53D1zeR_xBDVW                   Fast Food Restaurant,Restaurants
#
#                 city                            name province
# 0            Greeley                      Carl's Jr.       CO
# 1     Grand Junction                        Del Taco       CO
# 2     Grand Junction                      Which Wich       CO
# 3             Aurora          Chipotle Mexican Grill       CO
# 4             Denver                       Taco Bell       CO
# ...              ...                             ...      ...
# 9995        Bessemer  Church's Chicken Of Birmingham       AL
# 9996         Raleigh                      Luxury Box       NC
# 9997          Plover                      McDonald's       WI
# 9998  Hendersonville                       Pizza Hut       TN
# 9999          Durham                     Burger King       NC
#
# [10000 rows x 5 columns]

# %%
#Rename columns
fast_food_transformed = fast_food_transformed.rename(columns={'id': 'ID', 'categories':'Categories', 
                                                              'city':'City', 'name':'Restaurant_Name', 
                                                              'province': 'State'})
fast_food_transformed
# Out:
#                         ID                                         Categories  \
# 0     AWrSh_KgsVYjT2BJAzaH  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1     AWEKlA-LIxWefVJwxG9B  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2     AWrSfAcYsVYjT2BJAzPt  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3     AWrSa3NAQTFama1Xpkbz  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4     AWrSaVGzZ4Yw-wtdgcaB  Fast Food Restaurants,Mexican Restaurants,Rest...
# ...                    ...                                                ...
# 9995  AVwd7U0T_7pvs4fz-fS_  American Restaurants,Caterers,Soul Food Restau...
# 9996  AV1XW1fF3D1zeR_xFKHL  Mexican Restaurants,Caterers,Delicatessens,Iri...
# 9997  AV5UVbkiRxPSIh2RiQxV  Carry-out food,Hot dog restaurants,Fast Food R...
# 9998  AVwc9BxYByjofQCxj_GW  Carry-out food,Caterers,Restaurant delivery se...
# 9999  AVzA_GF53D1zeR_xBDVW                   Fast Food Restaurant,Restaurants
#
#                 City                 Restaurant_Name State
# 0            Greeley                      Carl's Jr.    CO
# 1     Grand Junction                        Del Taco    CO
# 2     Grand Junction                      Which Wich    CO
# 3             Aurora          Chipotle Mexican Grill    CO
# 4             Denver                       Taco Bell    CO
# ...              ...                             ...   ...
# 9995        Bessemer  Church's Chicken Of Birmingham    AL
# 9996         Raleigh                      Luxury Box    NC
# 9997          Plover                      McDonald's    WI
# 9998  Hendersonville                       Pizza Hut    TN
# 9999          Durham                     Burger King    NC
#
# [10000 rows x 5 columns]

# %%
#Finding restaurant count of each state
fast_food_state = fast_food_transformed.groupby('State').count()
fast_food_state.rename(columns={'Restaurant_Name': 'Restaurant_Count'}, inplace = True)
fast_food_state
# Out:
#         ID  Categories  City  Restaurant_Count
# State
# AK      64          64    64                64
# AL     635         635   635               635
# AR     124         124   124               124
# AZ     186         186   186               186
# CA     727         727   727               727
# CO     154         154   154               154
# CT       1           1     1                 1
# DC      18          18    18                18
# DE      25          25    25                25
# FL     739         739   739               739
# GA     238         238   238               238
# HI      91          91    91                91
# IA     107         107   107               107
# ID      65          65    65                65
# IL     305         305   305               305
# IN     519         519   519               519
# KS      92          92    92                92
# KY     142         142   142               142
# LA     161         161   161               161
# MA       2           2     2                 2
# MD     114         114   114               114
# MI     210         210   210               210
# MN      83          83    83                83
# MO     244         244   244               244
# MS      99          99    99                99
# MT      33          33    33                33
# NC     663         663   663               663
# ND      18          18    18                18
# NE      74          74    74                74
# NJ       2           2     2                 2
# NM      69          69    69                69
# NV      96          96    96                96
# NY     173         173   173               173
# OH     922         922   922               922
# OK     147         147   147               147
# OR     334         334   334               334
# PA     194         194   194               194
# SC     322         322   322               322
# SD      27          27    27                27
# TN     243         243   243               243
# TX     426         426   426               426
# UT      74          74    74                74
# VA     348         348   348               348
# WA     404         404   404               404
# WI     112         112   112               112
# WV     154         154   154               154
# WY      20          20    20                20

# %%
#Sorting by states with most restaurants
fast_food_state[['Restaurant_Count']].sort_values('Restaurant_Count',ascending=False)
# Out:
#        Restaurant_Count
# State
# OH                  922
# FL                  739
# CA                  727
# NC                  663
# AL                  635
# IN                  519
# TX                  426
# WA                  404
# VA                  348
# OR                  334
# SC                  322
# IL                  305
# MO                  244
# TN                  243
# GA                  238
# MI                  210
# PA                  194
# AZ                  186
# NY                  173
# LA                  161
# CO                  154
# WV                  154
# OK                  147
# KY                  142
# AR                  124
# MD                  114
# WI                  112
# IA                  107
# MS                   99
# NV                   96
# KS                   92
# HI                   91
# MN                   83
# UT                   74
# NE                   74
# NM                   69
# ID                   65
# AK                   64
# MT                   33
# SD                   27
# DE                   25
# WY                   20
# ND                   18
# DC                   18
# NJ                    2
# MA                    2
# CT                    1

# %%
#Import population by state
population = "US_population_2018.csv"
population = pd.read_csv(population)
population.head()
# Out:
#    Unnamed: 0         State  Population estimate, July 1, 2019[2]  \
# 0           0    California                              39512223
# 1           1         Texas                              28995881
# 2           2       Florida                              21477737
# 3           3      New York                              19453561
# 4           4  Pennsylvania                              12801989
#
#   Percent change, 2010–2019[note 1]  \
# 0                              6.1%
# 1                             15.3%
# 2                             14.2%
# 3                              0.4%
# 4                              0.8%
#
#   Percent of the total U.S. population, 2018[note 3]
# 0                                             11.96%
# 1                                              8.68%
# 2                                              6.44%
# 3                                              5.91%
# 4                                              3.87%

# %%
#Push population to database under table name: population
rds_connection_string = "postgres:postgres@localhost:5432/restaurant_db"
engine = create_engine(f'postgresql://{rds_connection_string}')
population.to_sql(name='population', con=engine, if_exists="append", index=False)

# %%
#Get state abbreviations from another source
url= 'https://simple.wikipedia.org/wiki/U.S._postal_abbreviations#States'
tables = pd.read_html(url)
tables
# Out:
# [                                                    0               1
#  0   State Abbreviation State Name AK Alaska AL Ala...             NaN
#  1                                  State Abbreviation      State Name
#  2                                                  AK          Alaska
#  3                                                  AL         Alabama
#  4                                                  AR        Arkansas
#  5                                                  AZ         Arizona
#  6                                                  CA      California
#  7                                                  CO        Colorado
#  8                                                  CT     Connecticut
#  9                                                  DE        Delaware
#  10                                                 FL         Florida
#  11                                                 GA         Georgia
#  12                                                 HI          Hawaii
#  13                                                 IA            Iowa
#  14                                                 ID           Idaho
#  15                                                 IL        Illinois
#  16                                                 IN         Indiana
#  17                                                 KS          Kansas
#  18                                                 KY        Kentucky
#  19                                                 LA       Louisiana
#  20                                                 MA   Massachusetts
#  21                                                 MD        Maryland
#  22                                                 ME           Maine
#  23                                                 MI        Michigan
#  24                                                 MN       Minnesota
#  25                                                 MO        Missouri
#  26                                                 MS     Mississippi
#  27                                                 MT         Montana
#  28                                                 NC  North Carolina
#  29                                                 ND    North Dakota
#  30                                                 NE        Nebraska
#  31                                                 NH   New Hampshire
#  32                                                 NJ      New Jersey
#  33                                                 NM      New Mexico
#  34                                                 NV          Nevada
#  35                                                 NY        New York
#  36                                                 OH            Ohio
#  37                                                 OK        Oklahoma
#  38                                                 OR          Oregon
#  39                                                 PA    Pennsylvania
#  40                                                 RI    Rhode Island
#  41                                                 SC  South Carolina
#  42                                                 SD    South Dakota
#  43                                                 TN       Tennessee
#  44                                                 TX           Texas
#  45                                                 UT            Utah
#  46                                                 VA        Virginia
#  47                                                 VT         Vermont
#  48                                                 WA      Washington
#  49                                                 WI       Wisconsin
#  50                                                 WV   West Virginia
#  51                                                 WY         Wyoming,
#     State Abbreviation      State Name
#  0                  AK          Alaska
#  1                  AL         Alabama
#  2                  AR        Arkansas
#  3                  AZ         Arizona
#  4                  CA      California
#  5                  CO        Colorado
#  6                  CT     Connecticut
#  7                  DE        Delaware
#  8                  FL         Florida
#  9                  GA         Georgia
#  10                 HI          Hawaii
#  11                 IA            Iowa
#  12                 ID           Idaho
#  13                 IL        Illinois
#  14                 IN         Indiana
#  15                 KS          Kansas
#  16                 KY        Kentucky
#  17                 LA       Louisiana
#  18                 MA   Massachusetts
#  19                 MD        Maryland
#  20                 ME           Maine
#  21                 MI        Michigan
#  22                 MN       Minnesota
#  23                 MO        Missouri
#  24                 MS     Mississippi
#  25                 MT         Montana
#  26                 NC  North Carolina
#  27                 ND    North Dakota
#  28                 NE        Nebraska
#  29                 NH   New Hampshire
#  30                 NJ      New Jersey
#  31                 NM      New Mexico
#  32                 NV          Nevada
#  33                 NY        New York
#  34                 OH            Ohio
#  35                 OK        Oklahoma
#  36                 OR          Oregon
#  37                 PA    Pennsylvania
#  38                 RI    Rhode Island
#  39                 SC  South Carolina
#  40                 SD    South Dakota
#  41                 TN       Tennessee
#  42                 TX           Texas
#  43                 UT            Utah
#  44                 VA        Virginia
#  45                 VT         Vermont
#  46                 WA      Washington
#  47                 WI       Wisconsin
#  48                 WV   West Virginia
#  49                 WY         Wyoming,
#    Abbreviation              Location
#  0           DC  District of Columbia,
#    Abbreviation                  Location
#  0           AS            American Samoa
#  1           GU                      Guam
#  2           MP  Northern Mariana Islands
#  3           PR               Puerto Rico
#  4           VI       U.S. Virgin Islands,
#    Abbreviation                        Location
#  0           FM  Federated States of Micronesia
#  1           MH                Marshall Islands
#  2           PW                           Palau,
#    Abbreviation                                           Location
#  0           AA              Armed Forces Americas (except Canada)
#  1           AE  Armed Forces Europe (covers all USARAEUR)Armed...
#  2           AP                               Armed Forces Pacific,
#    Abbreviation                                Location
#  0           CZ                              Canal Zone
#  1           TT  Trust Territory of the Pacific Islands
#  2           PI                             Rizal state]

# %%
#Pulling the first table and turning it into a dataframe
abbr_df=tables[1]
abbr_df
# Out:
#    State Abbreviation      State Name
# 0                  AK          Alaska
# 1                  AL         Alabama
# 2                  AR        Arkansas
# 3                  AZ         Arizona
# 4                  CA      California
# 5                  CO        Colorado
# 6                  CT     Connecticut
# 7                  DE        Delaware
# 8                  FL         Florida
# 9                  GA         Georgia
# 10                 HI          Hawaii
# 11                 IA            Iowa
# 12                 ID           Idaho
# 13                 IL        Illinois
# 14                 IN         Indiana
# 15                 KS          Kansas
# 16                 KY        Kentucky
# 17                 LA       Louisiana
# 18                 MA   Massachusetts
# 19                 MD        Maryland
# 20                 ME           Maine
# 21                 MI        Michigan
# 22                 MN       Minnesota
# 23                 MO        Missouri
# 24                 MS     Mississippi
# 25                 MT         Montana
# 26                 NC  North Carolina
# 27                 ND    North Dakota
# 28                 NE        Nebraska
# 29                 NH   New Hampshire
# 30                 NJ      New Jersey
# 31                 NM      New Mexico
# 32                 NV          Nevada
# 33                 NY        New York
# 34                 OH            Ohio
# 35                 OK        Oklahoma
# 36                 OR          Oregon
# 37                 PA    Pennsylvania
# 38                 RI    Rhode Island
# 39                 SC  South Carolina
# 40                 SD    South Dakota
# 41                 TN       Tennessee
# 42                 TX           Texas
# 43                 UT            Utah
# 44                 VA        Virginia
# 45                 VT         Vermont
# 46                 WA      Washington
# 47                 WI       Wisconsin
# 48                 WV   West Virginia
# 49                 WY         Wyoming

# %%
#Merging population df and abbr_df
populate_by_state=pd.merge(population, abbr_df, left_on='State', right_on='State Name')
populate_by_state.head()
# Out:
#    Unnamed: 0         State  Population estimate, July 1, 2019[2]  \
# 0           0    California                              39512223
# 1           1         Texas                              28995881
# 2           2       Florida                              21477737
# 3           3      New York                              19453561
# 4           4  Pennsylvania                              12801989
#
#   Percent change, 2010–2019[note 1]  \
# 0                              6.1%
# 1                             15.3%
# 2                             14.2%
# 3                              0.4%
# 4                              0.8%
#
#   Percent of the total U.S. population, 2018[note 3] State Abbreviation  \
# 0                                             11.96%                 CA
# 1                                              8.68%                 TX
# 2                                              6.44%                 FL
# 3                                              5.91%                 NY
# 4                                              3.87%                 PA
#
#      State Name
# 0    California
# 1         Texas
# 2       Florida
# 3      New York
# 4  Pennsylvania

# %%
#Finding the columns
populate_by_state.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Population estimate, July 1, 2019[2]',
#        'Percent change, 2010–2019[note 1]',
#        'Percent of the total U.S. population, 2018[note 3]',
#        'State Abbreviation', 'State Name'],
#       dtype='object')

# %%
#Dropping unnecessary columns
populate_by_state=populate_by_state.drop(["Unnamed: 0", "State"], axis=1)

# %%
#Reorganizing columns
populate_by_state=populate_by_state[["State Abbreviation", "State Name",'Population estimate, July 1, 2019[2]',
                                     'Percent change, 2010–2019[note 1]', 
                                     'Percent of the total U.S. population, 2018[note 3]']]

# %%
populate_by_state
# Out:
#    State Abbreviation      State Name  Population estimate, July 1, 2019[2]  \
# 0                  CA      California                              39512223
# 1                  TX           Texas                              28995881
# 2                  FL         Florida                              21477737
# 3                  NY        New York                              19453561
# 4                  PA    Pennsylvania                              12801989
# 5                  IL        Illinois                              12671821
# 6                  OH            Ohio                              11689100
# 7                  GA         Georgia                              10617423
# 8                  NC  North Carolina                              10488084
# 9                  MI        Michigan                               9986857
# 10                 NJ      New Jersey                               8882190
# 11                 VA        Virginia                               8535519
# 12                 WA      Washington                               7614893
# 13                 AZ         Arizona                               7278717
# 14                 MA   Massachusetts                               6949503
# 15                 TN       Tennessee                               6833174
# 16                 IN         Indiana                               6732219
# 17                 MO        Missouri                               6137428
# 18                 MD        Maryland                               6045680
# 19                 WI       Wisconsin                               5822434
# 20                 CO        Colorado                               5758736
# 21                 MN       Minnesota                               5639632
# 22                 SC  South Carolina                               5148714
# 23                 AL         Alabama                               4903185
# 24                 LA       Louisiana                               4648794
# 25                 KY        Kentucky                               4467673
# 26                 OR          Oregon                               4217737
# 27                 OK        Oklahoma                               3956971
# 28                 CT     Connecticut                               3565287
# 29                 UT            Utah                               3205958
# 30                 IA            Iowa                               3155070
# 31                 NV          Nevada                               3080156
# 32                 AR        Arkansas                               3017825
# 33                 MS     Mississippi                               2976149
# 34                 KS          Kansas                               2913314
# 35                 NM      New Mexico                               2096829
# 36                 NE        Nebraska                               1934408
# 37                 ID           Idaho                               1787065
# 38                 WV   West Virginia                               1792147
# 39                 HI          Hawaii                               1415872
# 40                 NH   New Hampshire                               1359711
# 41                 ME           Maine                               1344212
# 42                 MT         Montana                               1068778
# 43                 RI    Rhode Island                               1059361
# 44                 DE        Delaware                                973764
# 45                 SD    South Dakota                                884659
# 46                 ND    North Dakota                                762062
# 47                 AK          Alaska                                731545
# 48                 VT         Vermont                                623989
# 49                 WY         Wyoming                                578759
#
#    Percent change, 2010–2019[note 1]  \
# 0                               6.1%
# 1                              15.3%
# 2                              14.2%
# 3                               0.4%
# 4                               0.8%
# 5                              -1.2%
# 6                               1.3%
# 7                               9.6%
# 8                              10.0%
# 9                               1.0%
# 10                              1.0%
# 11                              6.7%
# 12                             13.2%
# 13                             13.9%
# 14                              5.3%
# 15                              7.6%
# 16                              3.8%
# 17                              2.5%
# 18                              4.7%
# 19                              2.4%
# 20                             14.5%
# 21                              6.3%
# 22                             11.3%
# 23                              2.6%
# 24                              2.5%
# 25                              3.0%
# 26                             10.1%
# 27                              5.5%
# 28                             -0.2%
# 29                             16.0%
# 30                              3.6%
# 31                             14.1%
# 32                              3.5%
# 33                              0.3%
# 34                              2.1%
# 35                              1.8%
# 36                              5.9%
# 37                             14.0%
# 38                             -3.3%
# 39                              4.1%
# 40                              3.3%
# 41                              1.2%
# 42                              8.0%
# 43                              0.6%
# 44                              8.4%
# 45                              8.7%
# 46                             13.3%
# 47                              3.0%
# 48                             -0.3%
# 49                              2.7%
#
#    Percent of the total U.S. population, 2018[note 3]
# 0                                              11.96%
# 1                                               8.68%
# 2                                               6.44%
# 3                                               5.91%
# 4                                               3.87%
# 5                                               3.85%
# 6                                               3.53%
# 7                                               3.18%
# 8                                               3.14%
# 9                                               3.02%
# 10                                              2.69%
# 11                                              2.58%
# 12                                              2.28%
# 13                                              2.17%
# 14                                              2.09%
# 15                                              2.05%
# 16                                              2.02%
# 17                                              1.85%
# 18                                              1.83%
# 19                                              1.76%
# 20                                              1.72%
# 21                                              1.70%
# 22                                              1.54%
# 23                                              1.48%
# 24                                              1.41%
# 25                                              1.35%
# 26                                              1.27%
# 27                                              1.19%
# 28                                              1.08%
# 29                                              0.96%
# 30                                              0.95%
# 31                                              0.92%
# 32                                              0.91%
# 33                                              0.90%
# 34                                              0.88%
# 35                                              0.63%
# 36                                              0.58%
# 37                                              0.53%
# 38                                              0.55%
# 39                                              0.43%
# 40                                              0.41%
# 41                                              0.40%
# 42                                              0.32%
# 43                                              0.32%
# 44                                              0.29%
# 45                                              0.27%
# 46                                              0.23%
# 47                                              0.22%
# 48                                              0.19%
# 49                                              0.17%

# %%
#Renaming columns
populate_by_state=populate_by_state.rename(columns={'Population estimate, July 1, 2019[2]':"Population",
       'Percent change, 2010–2019[note 1]': 'Population Percent Change',
       'Percent of the total U.S. population, 2018[note 3]':"Percent of Total Population"})

# %%
populate_by_state
# Out:
#    State Abbreviation      State Name  Population Population Percent Change  \
# 0                  CA      California    39512223                      6.1%
# 1                  TX           Texas    28995881                     15.3%
# 2                  FL         Florida    21477737                     14.2%
# 3                  NY        New York    19453561                      0.4%
# 4                  PA    Pennsylvania    12801989                      0.8%
# 5                  IL        Illinois    12671821                     -1.2%
# 6                  OH            Ohio    11689100                      1.3%
# 7                  GA         Georgia    10617423                      9.6%
# 8                  NC  North Carolina    10488084                     10.0%
# 9                  MI        Michigan     9986857                      1.0%
# 10                 NJ      New Jersey     8882190                      1.0%
# 11                 VA        Virginia     8535519                      6.7%
# 12                 WA      Washington     7614893                     13.2%
# 13                 AZ         Arizona     7278717                     13.9%
# 14                 MA   Massachusetts     6949503                      5.3%
# 15                 TN       Tennessee     6833174                      7.6%
# 16                 IN         Indiana     6732219                      3.8%
# 17                 MO        Missouri     6137428                      2.5%
# 18                 MD        Maryland     6045680                      4.7%
# 19                 WI       Wisconsin     5822434                      2.4%
# 20                 CO        Colorado     5758736                     14.5%
# 21                 MN       Minnesota     5639632                      6.3%
# 22                 SC  South Carolina     5148714                     11.3%
# 23                 AL         Alabama     4903185                      2.6%
# 24                 LA       Louisiana     4648794                      2.5%
# 25                 KY        Kentucky     4467673                      3.0%
# 26                 OR          Oregon     4217737                     10.1%
# 27                 OK        Oklahoma     3956971                      5.5%
# 28                 CT     Connecticut     3565287                     -0.2%
# 29                 UT            Utah     3205958                     16.0%
# 30                 IA            Iowa     3155070                      3.6%
# 31                 NV          Nevada     3080156                     14.1%
# 32                 AR        Arkansas     3017825                      3.5%
# 33                 MS     Mississippi     2976149                      0.3%
# 34                 KS          Kansas     2913314                      2.1%
# 35                 NM      New Mexico     2096829                      1.8%
# 36                 NE        Nebraska     1934408                      5.9%
# 37                 ID           Idaho     1787065                     14.0%
# 38                 WV   West Virginia     1792147                     -3.3%
# 39                 HI          Hawaii     1415872                      4.1%
# 40                 NH   New Hampshire     1359711                      3.3%
# 41                 ME           Maine     1344212                      1.2%
# 42                 MT         Montana     1068778                      8.0%
# 43                 RI    Rhode Island     1059361                      0.6%
# 44                 DE        Delaware      973764                      8.4%
# 45                 SD    South Dakota      884659                      8.7%
# 46                 ND    North Dakota      762062                     13.3%
# 47                 AK          Alaska      731545                      3.0%
# 48                 VT         Vermont      623989                     -0.3%
# 49                 WY         Wyoming      578759                      2.7%
#
#    Percent of Total Population
# 0                       11.96%
# 1                        8.68%
# 2                        6.44%
# 3                        5.91%
# 4                        3.87%
# 5                        3.85%
# 6                        3.53%
# 7                        3.18%
# 8                        3.14%
# 9                        3.02%
# 10                       2.69%
# 11                       2.58%
# 12                       2.28%
# 13                       2.17%
# 14                       2.09%
# 15                       2.05%
# 16                       2.02%
# 17                       1.85%
# 18                       1.83%
# 19                       1.76%
# 20                       1.72%
# 21                       1.70%
# 22                       1.54%
# 23                       1.48%
# 24                       1.41%
# 25                       1.35%
# 26                       1.27%
# 27                       1.19%
# 28                       1.08%
# 29                       0.96%
# 30                       0.95%
# 31                       0.92%
# 32                       0.91%
# 33                       0.90%
# 34                       0.88%
# 35                       0.63%
# 36                       0.58%
# 37                       0.53%
# 38                       0.55%
# 39                       0.43%
# 40                       0.41%
# 41                       0.40%
# 42                       0.32%
# 43                       0.32%
# 44                       0.29%
# 45                       0.27%
# 46                       0.23%
# 47                       0.22%
# 48                       0.19%
# 49                       0.17%

# %%
#Dropping unnecessary columns
populate_by_state=populate_by_state.drop(["Population Percent Change"], axis=1)

# %%
populate_by_state=populate_by_state.reset_index()

# %%
#Renaming columns
populate_by_state=populate_by_state.rename(columns={"index":"id", "population": "Population"})
populate_by_state
# Out:
#     id State Abbreviation      State Name  Population  \
# 0    0                 CA      California    39512223
# 1    1                 TX           Texas    28995881
# 2    2                 FL         Florida    21477737
# 3    3                 NY        New York    19453561
# 4    4                 PA    Pennsylvania    12801989
# 5    5                 IL        Illinois    12671821
# 6    6                 OH            Ohio    11689100
# 7    7                 GA         Georgia    10617423
# 8    8                 NC  North Carolina    10488084
# 9    9                 MI        Michigan     9986857
# 10  10                 NJ      New Jersey     8882190
# 11  11                 VA        Virginia     8535519
# 12  12                 WA      Washington     7614893
# 13  13                 AZ         Arizona     7278717
# 14  14                 MA   Massachusetts     6949503
# 15  15                 TN       Tennessee     6833174
# 16  16                 IN         Indiana     6732219
# 17  17                 MO        Missouri     6137428
# 18  18                 MD        Maryland     6045680
# 19  19                 WI       Wisconsin     5822434
# 20  20                 CO        Colorado     5758736
# 21  21                 MN       Minnesota     5639632
# 22  22                 SC  South Carolina     5148714
# 23  23                 AL         Alabama     4903185
# 24  24                 LA       Louisiana     4648794
# 25  25                 KY        Kentucky     4467673
# 26  26                 OR          Oregon     4217737
# 27  27                 OK        Oklahoma     3956971
# 28  28                 CT     Connecticut     3565287
# 29  29                 UT            Utah     3205958
# 30  30                 IA            Iowa     3155070
# 31  31                 NV          Nevada     3080156
# 32  32                 AR        Arkansas     3017825
# 33  33                 MS     Mississippi     2976149
# 34  34                 KS          Kansas     2913314
# 35  35                 NM      New Mexico     2096829
# 36  36                 NE        Nebraska     1934408
# 37  37                 ID           Idaho     1787065
# 38  38                 WV   West Virginia     1792147
# 39  39                 HI          Hawaii     1415872
# 40  40                 NH   New Hampshire     1359711
# 41  41                 ME           Maine     1344212
# 42  42                 MT         Montana     1068778
# 43  43                 RI    Rhode Island     1059361
# 44  44                 DE        Delaware      973764
# 45  45                 SD    South Dakota      884659
# 46  46                 ND    North Dakota      762062
# 47  47                 AK          Alaska      731545
# 48  48                 VT         Vermont      623989
# 49  49                 WY         Wyoming      578759
#
#    Percent of Total Population
# 0                       11.96%
# 1                        8.68%
# 2                        6.44%
# 3                        5.91%
# 4                        3.87%
# 5                        3.85%
# 6                        3.53%
# 7                        3.18%
# 8                        3.14%
# 9                        3.02%
# 10                       2.69%
# 11                       2.58%
# 12                       2.28%
# 13                       2.17%
# 14                       2.09%
# 15                       2.05%
# 16                       2.02%
# 17                       1.85%
# 18                       1.83%
# 19                       1.76%
# 20                       1.72%
# 21                       1.70%
# 22                       1.54%
# 23                       1.48%
# 24                       1.41%
# 25                       1.35%
# 26                       1.27%
# 27                       1.19%
# 28                       1.08%
# 29                       0.96%
# 30                       0.95%
# 31                       0.92%
# 32                       0.91%
# 33                       0.90%
# 34                       0.88%
# 35                       0.63%
# 36                       0.58%
# 37                       0.53%
# 38                       0.55%
# 39                       0.43%
# 40                       0.41%
# 41                       0.40%
# 42                       0.32%
# 43                       0.32%
# 44                       0.29%
# 45                       0.27%
# 46                       0.23%
# 47                       0.22%
# 48                       0.19%
# 49                       0.17%

# %% [markdown]
# # Loading

# %%
#Connect to local database - make sure to remove username/password before pushing to github
rds_connection_string = "<username>:<password>@localhost:5432/restaurant_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Exploring table names
engine.table_names()
# Out:
# ['restaurant', 'state_population', 'population']

# %%
#Pushing populate_by_state df to database
populate_by_state.to_sql(name='state_population', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from state_population', con=engine)
# Out:
#     id State Abbreviation      State Name  Population  \
# 0    0                 CA      California    39512223
# 1    1                 TX           Texas    28995881
# 2    2                 FL         Florida    21477737
# 3    3                 NY        New York    19453561
# 4    4                 PA    Pennsylvania    12801989
# 5    5                 IL        Illinois    12671821
# 6    6                 OH            Ohio    11689100
# 7    7                 GA         Georgia    10617423
# 8    8                 NC  North Carolina    10488084
# 9    9                 MI        Michigan     9986857
# 10  10                 NJ      New Jersey     8882190
# 11  11                 VA        Virginia     8535519
# 12  12                 WA      Washington     7614893
# 13  13                 AZ         Arizona     7278717
# 14  14                 MA   Massachusetts     6949503
# 15  15                 TN       Tennessee     6833174
# 16  16                 IN         Indiana     6732219
# 17  17                 MO        Missouri     6137428
# 18  18                 MD        Maryland     6045680
# 19  19                 WI       Wisconsin     5822434
# 20  20                 CO        Colorado     5758736
# 21  21                 MN       Minnesota     5639632
# 22  22                 SC  South Carolina     5148714
# 23  23                 AL         Alabama     4903185
# 24  24                 LA       Louisiana     4648794
# 25  25                 KY        Kentucky     4467673
# 26  26                 OR          Oregon     4217737
# 27  27                 OK        Oklahoma     3956971
# 28  28                 CT     Connecticut     3565287
# 29  29                 UT            Utah     3205958
# 30  30                 IA            Iowa     3155070
# 31  31                 NV          Nevada     3080156
# 32  32                 AR        Arkansas     3017825
# 33  33                 MS     Mississippi     2976149
# 34  34                 KS          Kansas     2913314
# 35  35                 NM      New Mexico     2096829
# 36  36                 NE        Nebraska     1934408
# 37  37                 ID           Idaho     1787065
# 38  38                 WV   West Virginia     1792147
# 39  39                 HI          Hawaii     1415872
# 40  40                 NH   New Hampshire     1359711
# 41  41                 ME           Maine     1344212
# 42  42                 MT         Montana     1068778
# 43  43                 RI    Rhode Island     1059361
# 44  44                 DE        Delaware      973764
# 45  45                 SD    South Dakota      884659
# 46  46                 ND    North Dakota      762062
# 47  47                 AK          Alaska      731545
# 48  48                 VT         Vermont      623989
# 49  49                 WY         Wyoming      578759
#
#    Percent of Total Population
# 0                       11.96%
# 1                        8.68%
# 2                        6.44%
# 3                        5.91%
# 4                        3.87%
# 5                        3.85%
# 6                        3.53%
# 7                        3.18%
# 8                        3.14%
# 9                        3.02%
# 10                       2.69%
# 11                       2.58%
# 12                       2.28%
# 13                       2.17%
# 14                       2.09%
# 15                       2.05%
# 16                       2.02%
# 17                       1.85%
# 18                       1.83%
# 19                       1.76%
# 20                       1.72%
# 21                       1.70%
# 22                       1.54%
# 23                       1.48%
# 24                       1.41%
# 25                       1.35%
# 26                       1.27%
# 27                       1.19%
# 28                       1.08%
# 29                       0.96%
# 30                       0.95%
# 31                       0.92%
# 32                       0.91%
# 33                       0.90%
# 34                       0.88%
# 35                       0.63%
# 36                       0.58%
# 37                       0.53%
# 38                       0.55%
# 39                       0.43%
# 40                       0.41%
# 41                       0.40%
# 42                       0.32%
# 43                       0.32%
# 44                       0.29%
# 45                       0.27%
# 46                       0.23%
# 47                       0.22%
# 48                       0.19%
# 49                       0.17%

# %%
#Exploring columns in fast_food_transformed df
fast_food_transformed.columns
# Out:
# Index(['ID', 'Categories', 'City', 'Restaurant_Name', 'State'], dtype='object')

# %%
#Pushing fast_food_transformed df to database
fast_food_transformed.to_sql(name="restaurant", con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from restaurant', con=engine)
# Out:
#                         ID                                         Categories  \
# 0     AWrSh_KgsVYjT2BJAzaH  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1     AWEKlA-LIxWefVJwxG9B  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2     AWrSfAcYsVYjT2BJAzPt  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3     AWrSa3NAQTFama1Xpkbz  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4     AWrSaVGzZ4Yw-wtdgcaB  Fast Food Restaurants,Mexican Restaurants,Rest...
# ...                    ...                                                ...
# 9995  AVwd7U0T_7pvs4fz-fS_  American Restaurants,Caterers,Soul Food Restau...
# 9996  AV1XW1fF3D1zeR_xFKHL  Mexican Restaurants,Caterers,Delicatessens,Iri...
# 9997  AV5UVbkiRxPSIh2RiQxV  Carry-out food,Hot dog restaurants,Fast Food R...
# 9998  AVwc9BxYByjofQCxj_GW  Carry-out food,Caterers,Restaurant delivery se...
# 9999  AVzA_GF53D1zeR_xBDVW                   Fast Food Restaurant,Restaurants
#
#                 City                 Restaurant_Name State
# 0            Greeley                      Carl's Jr.    CO
# 1     Grand Junction                        Del Taco    CO
# 2     Grand Junction                      Which Wich    CO
# 3             Aurora          Chipotle Mexican Grill    CO
# 4             Denver                       Taco Bell    CO
# ...              ...                             ...   ...
# 9995        Bessemer  Church's Chicken Of Birmingham    AL
# 9996         Raleigh                      Luxury Box    NC
# 9997          Plover                      McDonald's    WI
# 9998  Hendersonville                       Pizza Hut    TN
# 9999          Durham                     Burger King    NC
#
# [10000 rows x 5 columns]

# %%
#Top 15 states by restaurant count --- only showing 46 states???
top_15_rest_count = pd.read_sql_query('SELECT r."State", s."Population", COUNT(r."Restaurant_Name") restaurant_count FROM state_population s\
                  JOIN restaurant r ON s."State Abbreviation" = r."State"\
                  GROUP BY r."State", s."Population" ORDER BY restaurant_count DESC LIMIT 15;', con=engine)
top_15_rest_count
# Out:
#    State  Population  restaurant_count
# 0     OH    11689100               922
# 1     FL    21477737               739
# 2     CA    39512223               727
# 3     NC    10488084               663
# 4     AL     4903185               635
# 5     IN     6732219               519
# 6     TX    28995881               426
# 7     WA     7614893               404
# 8     VA     8535519               348
# 9     OR     4217737               334
# 10    SC     5148714               322
# 11    IL    12671821               305
# 12    MO     6137428               244
# 13    TN     6833174               243
# 14    GA    10617423               238

# %%
top_15_rest_count = plt.bar(top_15_rest_count['State'], top_15_rest_count['restaurant_count'])

# %%
#Number of restaurants in the top 15 most populous states
rest_most_pop_state = pd.read_sql_query('SELECT r."State", s."Population", COUNT(r."Restaurant_Name") restaurant_count FROM state_population s\
                  JOIN restaurant r ON s."State Abbreviation" = r."State"\
                  GROUP BY r."State", s."Population" ORDER BY s."Population" DESC LIMIT 15;', con=engine)
rest_most_pop_state
# Out:
#    State  Population  restaurant_count
# 0     CA    39512223               727
# 1     TX    28995881               426
# 2     FL    21477737               739
# 3     NY    19453561               173
# 4     PA    12801989               194
# 5     IL    12671821               305
# 6     OH    11689100               922
# 7     GA    10617423               238
# 8     NC    10488084               663
# 9     MI     9986857               210
# 10    NJ     8882190                 2
# 11    VA     8535519               348
# 12    WA     7614893               404
# 13    AZ     7278717               186
# 14    MA     6949503                 2

# %%
####OTHER thoughts and ideas...

# %%
#Most fast food categories by state
rest_categories = pd.read_sql_query('SELECT s."State Name", r."Categories", COUNT(r."Categories") restaurant_categories FROM state_population s\
                                JOIN restaurant r ON s."State Abbreviation" = r."State"\
                                GROUP BY r."Categories", s."State Name"\
                                ORDER BY COUNT(r."Categories") DESC LIMIT 15', con=engine)
rest_categories
# Out:
#         State Name                                         Categories  \
# 0       California                      Fast Food,Chicken,Restaurants
# 1          Florida                                          Fast Food
# 2         Missouri  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 3             Ohio                                          Fast Food
# 4            Texas  Fast Food,Soda Fountain Shops,Chicken,Hamburge...
# 5          Arizona  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 6       California  Restaurant,Mexican,Breakfast,Vegetarian,Fast F...
# 7   North Carolina  Ice Cream Parlors,Breakfast,Fast Food,Coffeeho...
# 8         Michigan  Ice Cream Parlors,Breakfast,Fast Food,Coffeeho...
# 9         Illinois  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 10  North Carolina  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 11           Texas                               Fast Food Restaurant
# 12        Missouri  Fast Food Restaurants,Restaurants,Sandwich Sho...
# 13         Arizona  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 14            Ohio  Delis And Delicatessens,Restaurant,Carry-out f...
#
#     restaurant_categories
# 0                      20
# 1                      19
# 2                      17
# 3                      16
# 4                      16
# 5                      14
# 6                      13
# 7                      13
# 8                      13
# 9                      13
# 10                     11
# 11                     11
# 12                     11
# 13                     10
# 14                     10

# %%
#trying to show percent of total population and restaurant count.. not decending correctly???
tot_pop_rest = pd.read_sql_query('SELECT r."State", s."Percent of Total Population", COUNT(r."Restaurant_Name") restaurant_count FROM state_population s\
                                 JOIN restaurant r ON s."State Abbreviation" = r."State"\
                                GROUP BY s."Percent of Total Population", r."State" ORDER BY s."Percent of Total Population" DESC', con=engine)
tot_pop_rest
# Out:
#    State Percent of Total Population  restaurant_count
# 0     TX                       8.68%               426
# 1     FL                       6.44%               739
# 2     NY                       5.91%               173
# 3     PA                       3.87%               194
# 4     IL                       3.85%               305
# 5     OH                       3.53%               922
# 6     GA                       3.18%               238
# 7     NC                       3.14%               663
# 8     MI                       3.02%               210
# 9     NJ                       2.69%                 2
# 10    VA                       2.58%               348
# 11    WA                       2.28%               404
# 12    AZ                       2.17%               186
# 13    MA                       2.09%                 2
# 14    TN                       2.05%               243
# 15    IN                       2.02%               519
# 16    CA                      11.96%               727
# 17    MO                       1.85%               244
# 18    MD                       1.83%               114
# 19    WI                       1.76%               112
# 20    CO                       1.72%               154
# 21    MN                       1.70%                83
# 22    SC                       1.54%               322
# 23    AL                       1.48%               635
# 24    LA                       1.41%               161
# 25    KY                       1.35%               142
# 26    OR                       1.27%               334
# 27    OK                       1.19%               147
# 28    CT                       1.08%                 1
# 29    UT                       0.96%                74
# 30    IA                       0.95%               107
# 31    NV                       0.92%                96
# 32    AR                       0.91%               124
# 33    MS                       0.90%                99
# 34    KS                       0.88%                92
# 35    NM                       0.63%                69
# 36    NE                       0.58%                74
# 37    WV                       0.55%               154
# 38    ID                       0.53%                65
# 39    HI                       0.43%                91
# 40    MT                       0.32%                33
# 41    DE                       0.29%                25
# 42    SD                       0.27%                27
# 43    ND                       0.23%                18
# 44    AK                       0.22%                64
# 45    WY                       0.17%                20

# %%
#trying to group by state and restaurant name - why is this not grouping by state??
state_rest = pd.read_sql_query('SELECT s."State Name", r."Restaurant_Name", COUNT(r."Restaurant_Name") Restaurant_Name_Count FROM state_population s\
                                JOIN restaurant r ON s."State Abbreviation" = r."State"\
                                GROUP BY r."Restaurant_Name", s."State Name"\
                                ORDER BY Restaurant_Name_Count DESC;', con=engine)
state_rest
# Out:
#       State Name           Restaurant_Name  restaurant_name_count
# 0           Ohio                 Pizza Hut                     91
# 1           Ohio                    SUBWAY                     83
# 2     California                McDonald's                     60
# 3           Ohio                    Subway                     60
# 4        Florida                McDonald's                     55
# ...          ...                       ...                    ...
# 3171     Florida  Gyros King Subs & Salads                      1
# 3172     Indiana           John's Pizzeria                      1
# 3173   Tennessee    Chipotle Mexican Grill                      1
# 3174     Alabama                 Ocharleys                      1
# 3175    Maryland    Chipotle Mexican Grill                      1
#
# [3176 rows x 3 columns]

# %%
# maybe we could pick one state with the most restaurants?
one_state = pd.read_sql_query('SELECT s."State Name", r."Restaurant_Name", COUNT(r."Restaurant_Name") Restaurant_Name_Count FROM state_population s\
                                JOIN restaurant r ON s."State Abbreviation" = r."State"\
                                WHERE s."State Name" = "Ohio"\
                                GROUP BY r."Restaurant_Name", s."State Name"\
                                ORDER BY Restaurant_Name_Count DESC;', con=engine)
one_state
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1277                     self.dialect.do_execute(
# -> 1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedColumn: column "Ohio" does not exist
# LINE 1: ...                           WHERE s."State Name" = "Ohio"    ...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-52-6c5ee8b7d413> in <module>
#       4                                 WHERE s."State Name" = "Ohio"\
#       5                                 GROUP BY r."Restaurant_Name", s."State Name"\
# ----> 6                                 ORDER BY Restaurant_Name_Count DESC;', con=engine)
#       7 one_state
#
# ~\anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2236
#    2237         connection = self._contextual_connect(close_with_result=True)
# -> 2238         return connection.execute(statement, *multiparams, **params)
#    2239
#    2240     def scalar(self, statement, *multiparams, **params):
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1179             parameters,
#    1180             statement,
# -> 1181             parameters,
#    1182         )
#    1183         if self._has_events or self.engine._has_events:
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1316         except BaseException as e:
#    1317             self._handle_dbapi_exception(
# -> 1318                 e, statement, parameters, cursor, context
#    1319             )
#    1320
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1510             elif should_wrap:
#    1511                 util.raise_(
# -> 1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#    1514             else:
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
#    1277                     self.dialect.do_execute(
# -> 1278                         cursor, statement, parameters, context
#    1279                     )
#    1280
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Ohio" does not exist
# LINE 1: ...                           WHERE s."State Name" = "Ohio"    ...
#                                                              ^
#
# [SQL: SELECT s."State Name", r."Restaurant_Name", COUNT(r."Restaurant_Name") Restaurant_Name_Count FROM state_population s                                JOIN restaurant r ON s."State Abbreviation" = r."State"                                WHERE s."State Name" = "Ohio"                                GROUP BY r."Restaurant_Name", s."State Name"                                ORDER BY Restaurant_Name_Count DESC;]
# (Background on this error at: http://sqlalche.me/e/13/f405)
