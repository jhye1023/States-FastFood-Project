# %% [markdown]
# # ETL Project

# %% [markdown]
# ## Import Dependencies and Setup

# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %% [markdown]
# ## Extract data

# %%
#Fastfood data from https://www.kaggle.com/datafiniti/fast-food-restaurants
fast_food_file = 'Resources/Fast_Food_Restaurants.csv'

# %%
#Fast food dataframe
fast_food_df = pd.read_csv(fast_food_file)
fast_food_df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AWrSh_KgsVYjT2BJAzaH  2019-05-19T23:58:05Z  2019-05-19T23:58:05Z
# 1  AWEKlA-LIxWefVJwxG9B  2018-01-18T18:30:23Z  2019-05-19T23:45:05Z
# 2  AWrSfAcYsVYjT2BJAzPt  2019-05-19T23:45:04Z  2019-05-19T23:45:04Z
# 3  AWrSa3NAQTFama1Xpkbz  2019-05-19T23:26:58Z  2019-05-19T23:26:58Z
# 4  AWrSaVGzZ4Yw-wtdgcaB  2019-05-19T23:24:38Z  2019-05-19T23:24:38Z
#
#                  address                                         categories  \
# 0       2555 11th Avenue  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1  2513 Highway 6 And 50  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2    1125 Patterson Road  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3    3455 N Salida Court  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4   5225 E Colfax Avenue  Fast Food Restaurants,Mexican Restaurants,Rest...
#
#                primaryCategories            city country  \
# ...

# %%
#US state population data from wikipedia to dataframe
url = 'https://simple.wikipedia.org/wiki/List_of_U.S._states_by_population'
pop_df = pd.read_html(url)[0]
pop_df
# Out:
#     Rank in states & territories, 2019  Rank in states & territories, 2010  \
# 0                                  1.0                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# 5                                  NaN                                 NaN
# 6                                  NaN                                 NaN
# 7                                  NaN                                 NaN
# 8                                  NaN                                 NaN
# 9                                  NaN                                 NaN
# 10                                 NaN                                 NaN
# ...

# %%
#Get state abbreviations
abbr_url= 'https://simple.wikipedia.org/wiki/U.S._postal_abbreviations#States'
state_abbr = pd.read_html(abbr_url)[1]
state_abbr
# Out:
#    State Abbreviation      State Name
# 0                  AK          Alaska
# 1                  AL         Alabama
# 2                  AR        Arkansas
# 3                  AZ         Arizona
# 4                  CA      California
# 5                  CO        Colorado
# 6                  CT     Connecticut
# 7                  DE        Delaware
# 8                  FL         Florida
# 9                  GA         Georgia
# 10                 HI          Hawaii
# 11                 IA            Iowa
# 12                 ID           Idaho
# 13                 IL        Illinois
# 14                 IN         Indiana
# 15                 KS          Kansas
# 16                 KY        Kentucky
# 17                 LA       Louisiana
# 18                 MA   Massachusetts
# 19                 MD        Maryland
# 20                 ME           Maine
# 21                 MI        Michigan
# 22                 MN       Minnesota
# 23                 MO        Missouri
# ...

# %% [markdown]
# ## Transforming data

# %%
#Creating a filtered dataframe from specific columns
fast_food_cols = ['id', 'categories', 'city', 'name', 'province']
fast_food_transformed = fast_food_df[fast_food_cols].copy()
fast_food_transformed
# Out:
#                         id                                         categories  \
# 0     AWrSh_KgsVYjT2BJAzaH  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1     AWEKlA-LIxWefVJwxG9B  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2     AWrSfAcYsVYjT2BJAzPt  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3     AWrSa3NAQTFama1Xpkbz  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4     AWrSaVGzZ4Yw-wtdgcaB  Fast Food Restaurants,Mexican Restaurants,Rest...
# ...                    ...                                                ...
# 9995  AVwd7U0T_7pvs4fz-fS_  American Restaurants,Caterers,Soul Food Restau...
# 9996  AV1XW1fF3D1zeR_xFKHL  Mexican Restaurants,Caterers,Delicatessens,Iri...
# 9997  AV5UVbkiRxPSIh2RiQxV  Carry-out food,Hot dog restaurants,Fast Food R...
# 9998  AVwc9BxYByjofQCxj_GW  Carry-out food,Caterers,Restaurant delivery se...
# 9999  AVzA_GF53D1zeR_xBDVW                   Fast Food Restaurant,Restaurants
#
# ...

# %%
#Rename columns
fast_food_transformed = fast_food_transformed.rename(columns={'id': 'ID', 'categories':'Categories', 
                                                              'city':'City',
                                                              'name':'Restaurant_Name', 'province': 'State'})
fast_food_transformed
# Out:
#                         ID                                         Categories  \
# 0     AWrSh_KgsVYjT2BJAzaH  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1     AWEKlA-LIxWefVJwxG9B  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2     AWrSfAcYsVYjT2BJAzPt  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3     AWrSa3NAQTFama1Xpkbz  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4     AWrSaVGzZ4Yw-wtdgcaB  Fast Food Restaurants,Mexican Restaurants,Rest...
# ...                    ...                                                ...
# 9995  AVwd7U0T_7pvs4fz-fS_  American Restaurants,Caterers,Soul Food Restau...
# 9996  AV1XW1fF3D1zeR_xFKHL  Mexican Restaurants,Caterers,Delicatessens,Iri...
# 9997  AV5UVbkiRxPSIh2RiQxV  Carry-out food,Hot dog restaurants,Fast Food R...
# 9998  AVwc9BxYByjofQCxj_GW  Carry-out food,Caterers,Restaurant delivery se...
# 9999  AVzA_GF53D1zeR_xBDVW                   Fast Food Restaurant,Restaurants
#
# ...

# %%
#Keeping specific columns
state_pop = ['State', 'Population estimate, July 1, 2019[2]', 'Percent change, 2010–2019[note 1]', 'Percent of the total U.S. population, 2018[note 3]']
populate_by_state = pop_df[state_pop].copy()
populate_by_state
# Out:
#                                           State  \
# 0                                    California
# 1                                         Texas
# 2                                       Florida
# 3                                      New York
# 4                                  Pennsylvania
# 5                                      Illinois
# 6                                          Ohio
# 7                                       Georgia
# 8                                North Carolina
# 9                                      Michigan
# 10                                   New Jersey
# 11                                     Virginia
# 12                                   Washington
# 13                                      Arizona
# 14                                Massachusetts
# 15                                    Tennessee
# 16                                      Indiana
# 17                                     Missouri
# ...

# %%
#Dropping non-states
populate_by_state = populate_by_state.drop([31,49,52,53,54,55,56,57,58,59])
populate_by_state=populate_by_state.reset_index()

# %%
populate_by_state.dtypes
# Out:
# index                                                  int64
# State                                                 object
# Population estimate, July 1, 2019[2]                   int64
# Percent change, 2010–2019[note 1]                     object
# Percent of the total U.S. population, 2018[note 3]    object
# dtype: object

# %%
#strip the % sign off data in the last column
populate_by_state['Percent of the total U.S. population, 2018[note 3]'] = list(map(lambda x: x[:-1], populate_by_state['Percent of the total U.S. population, 2018[note 3]'].values))
populate_by_state
# Out:
#     index           State  Population estimate, July 1, 2019[2]  \
# 0       0      California                              39512223
# 1       1           Texas                              28995881
# 2       2         Florida                              21477737
# 3       3        New York                              19453561
# 4       4    Pennsylvania                              12801989
# 5       5        Illinois                              12671821
# 6       6            Ohio                              11689100
# 7       7         Georgia                              10617423
# 8       8  North Carolina                              10488084
# 9       9        Michigan                               9986857
# 10     10      New Jersey                               8882190
# 11     11        Virginia                               8535519
# 12     12      Washington                               7614893
# 13     13         Arizona                               7278717
# ...

# %%
#change the datatyp of the last column to float
populate_by_state['Percent of the total U.S. population, 2018[note 3]'] = [float(x) for x in populate_by_state['Percent of the total U.S. population, 2018[note 3]'].values]
populate_by_state.dtypes
# Out:
# index                                                   int64
# State                                                  object
# Population estimate, July 1, 2019[2]                    int64
# Percent change, 2010–2019[note 1]                      object
# Percent of the total U.S. population, 2018[note 3]    float64
# dtype: object

# %%
#Merging population df and state abbreviations df
us_state_population=pd.merge(populate_by_state, state_abbr, left_on='State', right_on='State Name')
us_state_population
# Out:
#     index           State  Population estimate, July 1, 2019[2]  \
# 0       0      California                              39512223
# 1       1           Texas                              28995881
# 2       2         Florida                              21477737
# 3       3        New York                              19453561
# 4       4    Pennsylvania                              12801989
# 5       5        Illinois                              12671821
# 6       6            Ohio                              11689100
# 7       7         Georgia                              10617423
# 8       8  North Carolina                              10488084
# 9       9        Michigan                               9986857
# 10     10      New Jersey                               8882190
# 11     11        Virginia                               8535519
# 12     12      Washington                               7614893
# 13     13         Arizona                               7278717
# ...

# %%
#Dropping columns, keeping columns of interest, and renaming columns
us_state_population=us_state_population.drop(["State", "Percent change, 2010–2019[note 1]"], axis=1)
us_state_population=us_state_population[["index","State Abbreviation", "State Name",'Population estimate, July 1, 2019[2]',
       'Percent of the total U.S. population, 2018[note 3]']]
us_state_population=us_state_population.rename (columns={'index': 'id', 'Population estimate, July 1, 2019[2]':"Population",
       'Percent of the total U.S. population, 2018[note 3]':"Percent of Total Population"})

# %%
us_state_population
# Out:
#     id State Abbreviation      State Name  Population  \
# 0    0                 CA      California    39512223
# 1    1                 TX           Texas    28995881
# 2    2                 FL         Florida    21477737
# 3    3                 NY        New York    19453561
# 4    4                 PA    Pennsylvania    12801989
# 5    5                 IL        Illinois    12671821
# 6    6                 OH            Ohio    11689100
# 7    7                 GA         Georgia    10617423
# 8    8                 NC  North Carolina    10488084
# 9    9                 MI        Michigan     9986857
# 10  10                 NJ      New Jersey     8882190
# 11  11                 VA        Virginia     8535519
# 12  12                 WA      Washington     7614893
# 13  13                 AZ         Arizona     7278717
# 14  14                 MA   Massachusetts     6949503
# 15  15                 TN       Tennessee     6833174
# ...

# %% [markdown]
# # Loading Data Into Database

# %%
#Connect to local database - make sure to use local username and password in place of <username> and <password>
rds_connection_string = "<username>:<password>@localhost:5432/restaurant_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['restaurant', 'state_population']

# %%
#Pushing us_state_population df to database
us_state_population.to_sql(name='state_population', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from state_population', con=engine).head()
# Out:
#    id State Abbreviation    State Name  Population  \
# 0   0                 CA    California    39512223
# 1   1                 TX         Texas    28995881
# 2   2                 FL       Florida    21477737
# 3   3                 NY      New York    19453561
# 4   4                 PA  Pennsylvania    12801989
#
#    Percent of Total Population
# 0                        11.96
# 1                         8.68
# 2                         6.44
# 3                         5.91
# 4                         3.87

# %%
#Exploring columns in fast_food_transformed df
fast_food_transformed.columns
# Out:
# Index(['ID', 'Categories', 'City', 'Restaurant_Name', 'State'], dtype='object')

# %%
#Pushing fast_food_transformed df to database
fast_food_transformed.to_sql(name="restaurant", con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from restaurant', con=engine).head()
# Out:
#                      ID                                         Categories  \
# 0  AWrSh_KgsVYjT2BJAzaH  Fast Food Restaurants,Hamburgers and Hot Dogs,...
# 1  AWEKlA-LIxWefVJwxG9B  Restaurant,Mexican Restaurants,Fast Food Resta...
# 2  AWrSfAcYsVYjT2BJAzPt  Sandwich Shops,Fast Food Restaurants,Restauran...
# 3  AWrSa3NAQTFama1Xpkbz  Fast Food Restaurants,Mexican Restaurants,Rest...
# 4  AWrSaVGzZ4Yw-wtdgcaB  Fast Food Restaurants,Mexican Restaurants,Rest...
#
#              City         Restaurant_Name State
# 0         Greeley              Carl's Jr.    CO
# 1  Grand Junction                Del Taco    CO
# 2  Grand Junction              Which Wich    CO
# 3          Aurora  Chipotle Mexican Grill    CO
# 4          Denver               Taco Bell    CO

# %% [markdown]
# # Data Exploration

# %%
#Top 15 states by restaurant count
top_15_rest_count = pd.read_sql_query('SELECT r."State", s."Population", COUNT(r."Restaurant_Name") restaurant_count FROM state_population s\
                  JOIN restaurant r ON s."State Abbreviation" = r."State"\
                  GROUP BY r."State", s."Population" ORDER BY restaurant_count DESC LIMIT 15;', con=engine)
top_15_rest_count
# Out:
#    State  Population  restaurant_count
# 0     OH    11689100               922
# 1     FL    21477737               739
# 2     CA    39512223               727
# 3     NC    10488084               663
# 4     AL     4903185               635
# 5     IN     6732219               519
# 6     TX    28995881               426
# 7     WA     7614893               404
# 8     VA     8535519               348
# 9     OR     4217737               334
# 10    SC     5148714               322
# 11    IL    12671821               305
# 12    MO     6137428               244
# 13    TN     6833174               243
# 14    GA    10617423               238

# %%
#Creating bar graph for total fast food restaurants per state
plt.figure(figsize=(15,10))
top_15_rest_count = plt.bar(top_15_rest_count['State'], top_15_rest_count['restaurant_count'])
plt.xlabel('States', size = 14)
plt.xticks(size = 12)
plt.ylabel('Restaurant Count', size = 14)
plt.yticks(size = 12)
plt.title('Total Fast Food Restaurants Per State', size=18)
plt.savefig('Images/Top15StatesByRestCount.png')
plt.show()

# %%
#Number of restaurants in the top 15 most populous states
rest_most_pop_state = pd.read_sql_query('SELECT r."State", s."Population", COUNT(r."Restaurant_Name") restaurant_count FROM state_population s\
                  JOIN restaurant r ON s."State Abbreviation" = r."State"\
                  GROUP BY r."State", s."Population" ORDER BY s."Population" DESC LIMIT 15;', con=engine)
rest_most_pop_state
# Out:
#    State  Population  restaurant_count
# 0     CA    39512223               727
# 1     TX    28995881               426
# 2     FL    21477737               739
# 3     NY    19453561               173
# 4     PA    12801989               194
# 5     IL    12671821               305
# 6     OH    11689100               922
# 7     GA    10617423               238
# 8     NC    10488084               663
# 9     MI     9986857               210
# 10    NJ     8882190                 2
# 11    VA     8535519               348
# 12    WA     7614893               404
# 13    AZ     7278717               186
# 14    MA     6949503                 2

# %%
#Creating bar graph for number of restaurants in the top 15 most populous states
plt.figure(figsize=(15,10))
rest_most_pop_state_plt = plt.bar(rest_most_pop_state['State'], rest_most_pop_state['restaurant_count'], color = 'm', alpha = .5)
plt.xlabel('States', size = 14)
plt.xticks(size = 12)
plt.ylabel('Restaurant Count', size = 14)
plt.yticks(size = 12)
plt.title('Total Fast Food Restaurants In Top 15 Populous States', size=18)
plt.savefig('Images/Top15MostPopulousRestCount.png')
plt.show()

# %%
#Ohio restaurants
ohio_restaurant = pd.read_sql_query('SELECT s."State Name", r."Restaurant_Name", COUNT(r."Restaurant_Name") Restaurant_Name_Count FROM state_population s\
                                JOIN restaurant r ON s."State Abbreviation" = r."State"\
                                WHERE s."State Name" = \'Ohio\'\
                                GROUP BY r."Restaurant_Name", s."State Name"\
                                ORDER BY Restaurant_Name_Count DESC LIMIT 10;', con=engine)
ohio_restaurant
# Out:
#   State Name         Restaurant_Name  restaurant_name_count
# 0       Ohio               Pizza Hut                     91
# 1       Ohio                  SUBWAY                     83
# 2       Ohio                  Subway                     60
# 3       Ohio             Dairy Queen                     49
# 4       Ohio              McDonald's                     41
# 5       Ohio  Chipotle Mexican Grill                     39
# 6       Ohio            Panera Bread                     34
# 7       Ohio               Taco Bell                     32
# 8       Ohio                     KFC                     32
# 9       Ohio                  Arby's                     20

# %%
#Creating bar graph for number of restaurants Ohio
plt.figure(figsize=(15,10))
ohio_plt = plt.bar(ohio_restaurant['Restaurant_Name'], ohio_restaurant['restaurant_name_count'], color = 'r', alpha =.6)
plt.xlabel('Restaurant Name', size = 14)
plt.xticks(size = 12, rotation=45)
plt.ylabel('Restaurant Count', size = 14)
plt.yticks(size = 12)
plt.title('Total Fast Food Restaurants In Ohio', size=18)
plt.savefig('Images/OhioRestCount.png')
plt.show()

# %%
#California restaurants
california_rest = pd.read_sql_query('SELECT s."State Name", r."Restaurant_Name", COUNT(r."Restaurant_Name") Restaurant_Name_Count FROM state_population s\
                                JOIN restaurant r ON s."State Abbreviation" = r."State"\
                                WHERE s."State Name" = \'California\'\
                                GROUP BY r."Restaurant_Name", s."State Name"\
                                ORDER BY Restaurant_Name_Count DESC LIMIT 10;', con=engine)
california_rest
# Out:
#    State Name    Restaurant_Name  restaurant_name_count
# 0  California         McDonald's                     60
# 1  California          Taco Bell                     47
# 2  California             SUBWAY                     44
# 3  California    Jack in the Box                     42
# 4  California                KFC                     37
# 5  California        Burger King                     34
# 6  California             Subway                     32
# 7  California      Panda Express                     25
# 8  California           Del Taco                     18
# 9  California  Round Table Pizza                     17

# %%
#Creating bar graph for number of restaurants in California
plt.figure(figsize=(15,10))
cali_plt = plt.bar(california_rest['Restaurant_Name'], california_rest['restaurant_name_count'], color = 'c')
plt.xlabel('Restaurant Name', size = 14)
plt.xticks(size = 12, rotation=45)
plt.ylabel('Restaurant Count', size = 14)
plt.yticks(size = 12)
plt.title('Total Fast Food Restaurants In California', size=18)
plt.savefig('Images/CaliRestCount.png')
plt.show()
